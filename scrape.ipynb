# %% [markdown]
# # Steam Store and SteamSpy Scraping

# %% [markdown]
# ## Introduction
#
# In this file, I will be scraping data from the official Steam store and the SteamSpy API for game information. You will not have to run this page, since I will be including all the datasets in the Google Drive folder (and GitHub). If you would like to get updated data, or would like to make sure this page works, feel free to run to code.

# %% [markdown]
# # Scraping
#
# In order to begin scraping, I need to look for what data/games I want to specifically look for. Using the [Steam Reviews](https://www.kaggle.com/datasets/andrewmvd/steam-reviews) dataset by Larxel from Kaggle, I will find the app_ids of games I want to scrape to analyze. This dataset includes over 6.4 publicly available reviews in English, review sentiments, and the number of users who found the review helpful. In order to make the time to run the code reasonable, I will only be taking the first 1500 unique games from this dataset to analyze.

# %%
# Importing the necessary libraries for scraping
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time
import json
import altair as alt

# %%
df = pd.read_csv("steam_review_data.csv")
unique_ids = df['app_id'].dropna().unique()[:1500]

# %% [markdown]
# First, I will be scraping the game information from the official Steam Store. In order to do this, I appended the app_ids from the Steam Reviews dataset to the base Steam Store url. However, on the Steam Store, some games with a mature rating require an age verification. To bypass this check, I needed to add cookies like birthtime, lastagecheckage, and mature_content, so that when accessing this page, it will immediately open the game page instead of redirecting to age verification. Then, from this page, I extracted content like the game title, genre, developer, publisher, franchise, and release date and created a Pandas DataFrame using this data.
#
# NOTE: Code below took 37 minutes and 4 seconds to run on MacBook (VS Code); may take longer/shorter on Google Colab.

# %%
# Create cookies to bypass age verification
cookies = {
    'birthtime': '568022401',
    'lastagecheckage': '1-January-1990',
    'mature_content': '1'
}

base_url = "https://store.steampowered.com/app/"

# Created an array to store data before inputting to DataFrame
results = []

# For each game in unique_ids, navigate to the Steam page and extract data
for app_id in unique_ids:
    url = f"{base_url}{int(app_id)}/"
    try:
        response = requests.get(url, cookies=cookies, timeout=10)
        
        if response.status_code != 200:
            raise Exception(f"Bad status code {response.status_code} for app_id {app_id}")
        
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the HTML element with the information needed
        info_block = soup.find('div', id='genresAndManufacturer')

        # Make the data default to N/A if information is not found
        title = genre = developer = publisher = franchise = release_date = "N/A"

        if info_block:
            # Title
            title_line = info_block.find(string=lambda t: 'Title:' in t)
            if title_line:
                title = title_line.parent.next_sibling.strip()

            # Genre
            genre_line = info_block.find(string=lambda t: 'Genre:' in t)
            if genre_line:
                genre_span = genre_line.find_next('span')
                if genre_span:
                    genre = ', '.join([a.text.strip() for a in genre_span.find_all('a')])
            # Developer
            dev_block = info_block.find('b', string='Developer:')
            if dev_block:
                developer = ', '.join([a.text for a in dev_block.find_next_siblings('a')])

            # Publisher
            pub_block = info_block.find('b', string='Publisher:')
            if pub_block:
                publisher = ', '.join([a.text for a in pub_block.find_next_siblings('a')])

            # Franchise
            fr_block = info_block.find('b', string='Franchise:')
            if fr_block:
                franchise = ', '.join([a.text for a in fr_block.find_next_siblings('a')])

            # Release Date
            rel_line = info_block.find(text=lambda t: 'Release Date:' in t)
            if rel_line:
                release_date = rel_line.parent.next_sibling.strip()

        results.append({
            'app_id': app_id,
            'title': title,
            'genre': genre,
            'developer': developer,
            'publisher': publisher,
            'franchise': franchise,
            'release_date': release_date
        })

    # If there is an error, then make the row N/A
    except Exception as e:
        results.append({
            'app_id': app_id,
            'title': f"Error: {e}",
            'genre': "N/A",
            'developer': "N/A",
            'publisher': "N/A",
            'franchise': "N/A",
            'release_date': "N/A"
        })
    # Added sleep to make sure I don't make too many requests at once
    time.sleep(.5)

# Save results
output_df = pd.DataFrame(results)
output_df.to_csv("steam_game_details.csv", index=False)
print(output_df.head())

# %% [markdown]
# Then, to scrape data from the SteamSpy API, I parsed through the JSON that the API outputs and extract data like the number of positive/negative reviews, range of owners, price, and tags. Since the API only allows one request per second, I included a one second buffer for each call. And this data was saved as a Pandas DataFrame.
#
# NOTE: Code below took 63m and 34 seconds to run on Macbook (VS Code); may take longer/shorter on Google Colab

# %%
base_url = "https://steamspy.com/api.php?request=appdetails&appid="

# Created an array to store data before inputting to DataFrame
results = []

# For each app_id in unique_ids extract game information
for app_id in unique_ids:
    url = f"{base_url}{int(app_id)}/"
    try:
        response = requests.get(url)
        
        if response.status_code != 200:
            raise Exception(f"Bad status code {response.status_code} for app_id {app_id}")
        
        data = json.loads(response.text)
        
        # Getting data and storing in variables to append to results array
        positive = data['positive']
        negative = data['negative']
        owners = data['owners']
        price = data['price']
        tags = data['tags']
        results.append({
            'app_id': app_id,
            'positive': positive,
            'negative': negative,
            'owners': owners,
            'price': price,
            'tags': tags,
        })
        
    # If there is an error, then make the row N/A
    except Exception as e:
        results.append({
            'app_id': app_id,
            'positive': "N/A",
            'negative': "N/A",
            'owners': "N/A",
            'price': "N/A",
            'tags': "N/A",
        })
        print(e)

    # Added 1 second sleep to make sure that I don't send too many requests at once
    time.sleep(1)

# Save results
output_df = pd.DataFrame(results)
output_df.to_csv("steam_game_stats.csv", index=False)
print(output_df.head())
# Out:
# <Response [200]>
# {"appid":10,"name":"Counter-Strike","developer":"Valve","publisher":"Valve","score_rank":"","positive":242768,"negative":6388,"userscore":0,"owners":"10,000,000 .. 20,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":11198,"languages":"English, French, German, Italian, Spanish - Spain, Simplified Chinese, Traditional Chinese, Korean","genre":"Action","tags":{"Action":5499,"FPS":4924,"Multiplayer":3471,"Shooter":3417,"Classic":2847,"Team-Based":1920,"First-Person":1760,"Competitive":1654,"Tactical":1391,"1990's":1246,"e-sports":1232,"PvP":928,"Old School":828,"Military":665,"Strategy":640,"Survival":322,"Score Attack":304,"1980s":285,"Assassin":248,"Nostalgia":205}}
# <Response [200]>
# {"appid":1002,"name":"Rag Doll Kung Fu","developer":"Mark Healey","publisher":"Mark Healey","score_rank":"","positive":89,"negative":30,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"99","initialprice":"99","discount":"0","ccu":0,"languages":"English","genre":"Indie","tags":{"2D Fighter":47,"Martial Arts":41,"Intentionally Awkward Controls":31,"Physics":30,"Indie":29,"Multiplayer":29,"Fighting":27,"Singleplayer":27,"Action":26,"2D":18}}
# <Response [200]>
# {"appid":100400,"name":"Silo 2","developer":"Nevercenter Ltd. Co.","publisher":"Nevercenter Ltd. Co.","score_rank":"","positive":61,"negative":24,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"5999","initialprice":"5999","discount":"0","ccu":0,"languages":"English","genre":"Animation & Modeling","tags":{"Animation & Modeling":23,"Software":11}}
# <Response [200]>
# {"appid":10090,"name":"Call of Duty: World at War","developer":"Treyarch","publisher":"Activision","score_rank":"","positive":46341,"negative":3870,"userscore":0,"owners":"2,000,000 .. 5,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"1499","initialprice":"1999","discount":"25","ccu":432,"languages":"English, French, Italian, German, Spanish - Spain","genre":"Action","tags":{"Zombies":1197,"World War II":902,"FPS":892,"Multiplayer":797,"Action":760,"Shooter":748,"Singleplayer":669,"Co-op":668,"First-Person":604,"Moddable":598,"War":546,"Online Co-Op":481,"Gore":442,"Historical":406,"Classic":345,"Survival":318,"Great Soundtrack":293,"Horror":291,"Tanks":278,"Adventure":259}}
# <Response [200]>
# {"appid":100980,"name":"3DCoat 4.9","developer":"Pilgway","publisher":"Pilgway","score_rank":"","positive":129,"negative":17,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":8,"languages":"English, French, German, Japanese, Korean, Russian, Spanish - Spain, Traditional Chinese","genre":"Animation & Modeling, Design & Illustration, Education, Photo Editing, Utilities, Game Development","tags":{"Animation & Modeling":38,"Utilities":22,"Design & Illustration":21,"Photo Editing":21,"Education":21,"Game Development":21}}
# <Response [200]>
# {"appid":10100,"name":"King's Quest Collection","developer":"Sierra","publisher":"Activision","score_rank":"","positive":312,"negative":47,"userscore":0,"owners":"100,000 .. 200,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"1999","discount":"50","ccu":12,"languages":"English","genre":"Adventure","tags":{"Adventure":68,"Point & Click":53,"Classic":38,"Fantasy":28,"Retro":26,"Pixel Graphics":16,"Puzzle":13,"1990's":13,"1980s":12,"Singleplayer":10,"Old School":8,"2D":7,"Female Protagonist":7,"Escape Room":5}}
# <Response [200]>
# {"appid":10110,"name":"Space Quest Collection","developer":"Sierra","publisher":"Activision","score_rank":"","positive":314,"negative":58,"userscore":0,"owners":"100,000 .. 200,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"659","initialprice":"1999","discount":"67","ccu":3,"languages":"English","genre":"Adventure","tags":{"Adventure":70,"Point & Click":53,"Classic":45,"Comedy":33,"Retro":32,"Space":24,"1990's":21,"Futuristic":16,"Robots":14,"Survival":12,"Epic":12,"Replay Value":10,"2D":10,"Funny":7,"Singleplayer":7,"Remake":7,"Cult Classic":7,"Story Rich":6,"Escape Room":6}}
# <Response [200]>
# {"appid":10120,"name":"Aces of the Galaxy","developer":"Artech Studios","publisher":"Activision","score_rank":"","positive":22,"negative":23,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"329","initialprice":"999","discount":"67","ccu":0,"languages":"English, French, German, Italian, Spanish - Spain","genre":"Action, Casual","tags":{"Action":23,"Casual":22,"Space":11,"On-Rails Shooter":8,"Arcade":6}}
# <Response [200]>
# {"appid":10130,"name":"TimeShift","developer":"Saber Interactive","publisher":"Activision","score_rank":"","positive":1055,"negative":270,"userscore":0,"owners":"100,000 .. 200,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"1999","discount":"50","ccu":2,"languages":"English","genre":"Action","tags":{"Action":96,"FPS":91,"Time Manipulation":78,"Sci-fi":66,"Shooter":45,"First-Person":42,"Singleplayer":41,"Atmospheric":36,"Bullet Time":29,"Classic":25,"Multiplayer":22,"Futuristic":21,"Time Travel":21,"Alternate History":10,"Gore":8}}
# <Response [200]>
# {"appid":10140,"name":"3D Ultra Minigolf Adventures","developer":"Wanako Games","publisher":"Activision","score_rank":"","positive":86,"negative":39,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"329","initialprice":"999","discount":"67","ccu":0,"languages":"English","genre":"Sports","tags":{"Sports":55,"Mini Golf":38,"Golf":35,"Local Multiplayer":9,"Singleplayer":6}}
# <Response [200]>
# {"appid":10150,"name":"Prototype","developer":"Radical Entertainment","publisher":"Activision","score_rank":"","positive":9681,"negative":2380,"userscore":0,"owners":"1,000,000 .. 2,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"499","initialprice":"1999","discount":"75","ccu":86,"languages":"English, French, Spanish - Spain, Italian","genre":"Action, Adventure","tags":{"Action":573,"Open World":538,"Gore":357,"Singleplayer":338,"Third Person":321,"Adventure":318,"Superhero":313,"Parkour":292,"Violent":231,"Hack and Slash":207,"Zombies":205,"Action-Adventure":194,"Sci-fi":166,"Story Rich":142,"Sandbox":141,"RPG":130,"Stealth":115,"Atmospheric":94,"Controller":94,"Horror":88}}
# <Response [200]>
# {"appid":10180,"name":"Call of Duty: Modern Warfare 2 (2009)","developer":"Infinity Ward","publisher":"Activision","score_rank":"","positive":53921,"negative":3955,"userscore":0,"owners":"5,000,000 .. 10,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"1499","initialprice":"1999","discount":"25","ccu":400,"languages":"English, French, German, Italian, Spanish - Spain","genre":"Action","tags":{"Action":1825,"FPS":1517,"Multiplayer":1287,"Shooter":1016,"First-Person":841,"Singleplayer":778,"War":695,"Military":641,"Co-op":540,"Online Co-Op":509,"PvP":446,"Great Soundtrack":344,"Story Rich":325,"Atmospheric":247,"Controller":238,"Adventure":234,"Tactical":231,"Linear":190,"Strategy":165,"Moddable":157}}
# <Response [200]>
# {"appid":10220,"name":"Postal III","developer":"Trashmasters, Zoom Platform","publisher":"Akella","score_rank":"","positive":2348,"negative":2878,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"599","initialprice":"599","discount":"0","ccu":6,"languages":"English, Russian, German, French, Japanese, Polish, Portuguese - Brazil","genre":"Action","tags":{"Action":124,"Gore":100,"Dark Humor":97,"Violent":81,"Third-Person Shooter":77,"Funny":68,"Open World":67,"Third Person":60,"Singleplayer":57,"Shooter":53,"Comedy":53,"Psychological Horror":46,"Mature":46,"Sandbox":32,"Nudity":31,"Great Soundtrack":27,"Sexual Content":21,"Adventure":19,"Hentai":17,"Anime":14}}
# <Response [200]>
# {"appid":102200,"name":"Runespell: Overture","developer":"Mystic Box","publisher":"Mystic Box","score_rank":"","positive":286,"negative":99,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":0,"languages":"English","genre":"Adventure, Indie, RPG","tags":{"Card Battler":50,"Card Game":47,"Deckbuilding":46,"RPG":43,"Indie":42,"Casual":29,"Adventure":25,"Fantasy":18,"Singleplayer":15}}
# <Response [200]>
# {"appid":10230,"name":"Dead Mountaineer's Hotel","developer":"Electronic Paradise","publisher":"Akella","score_rank":"","positive":42,"negative":70,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"799","initialprice":"799","discount":"0","ccu":0,"languages":"English, German, Russian","genre":"Adventure","tags":{"Adventure":30,"Point & Click":18,"Atmospheric":5}}
# <Response [200]>
# {"appid":10240,"name":"A Stroke of Fate: Operation Valkyrie","developer":"SPLine","publisher":"Akella","score_rank":"","positive":20,"negative":12,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"699","initialprice":"699","discount":"0","ccu":0,"languages":"English","genre":"Adventure","tags":{"Adventure":27,"Point & Click":12,"World War II":6}}
# <Response [200]>
# {"appid":10250,"name":"PT Boats: Knights of the Sea","developer":"Studio4","publisher":"Akella","score_rank":"","positive":21,"negative":22,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"699","initialprice":"699","discount":"0","ccu":0,"languages":"English","genre":"Simulation","tags":{"Simulation":25,"Naval":5}}
# <Response [200]>
# {"appid":102500,"name":"Kingdoms of Amalur: Reckoning","developer":"Big Huge Games, 38 Studios","publisher":"38 Studios, Electronic Arts","score_rank":"","positive":11367,"negative":1553,"userscore":0,"owners":"1,000,000 .. 2,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":30,"languages":"English, French, German, Italian, Spanish - Spain","genre":"Action, RPG","tags":{"RPG":901,"Fantasy":628,"Open World":595,"Singleplayer":516,"Action RPG":456,"Action":428,"Adventure":361,"Third Person":347,"Loot":248,"Story Rich":241,"Magic":221,"Character Customization":205,"Hack and Slash":179,"Exploration":119,"Controller":100,"Sandbox":93,"Atmospheric":81,"Crafting":75,"Female Protagonist":63,"Great Soundtrack":37}}
# <Response [200]>
# {"appid":10260,"name":"PT Boats: South Gambit","developer":"studio4","publisher":"Akella","score_rank":"","positive":15,"negative":13,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"699","initialprice":"699","discount":"0","ccu":0,"languages":"English","genre":"Simulation","tags":{"Simulation":26,"World War II":5,"Naval":5}}
# <Response [200]>
# {"appid":102600,"name":"Orcs Must Die!","developer":"Robot Entertainment","publisher":"Robot Entertainment","score_rank":"","positive":7808,"negative":332,"userscore":0,"owners":"500,000 .. 1,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"299","initialprice":"999","discount":"70","ccu":32,"languages":"English, German, French, Italian, Spanish - Spain, Russian, Japanese, Polish, Portuguese - Brazil","genre":"Action, Indie, Strategy","tags":{"Tower Defense":503,"Action":303,"Strategy":261,"Third Person":208,"Fantasy":182,"Indie":170,"Singleplayer":169,"Comedy":134,"Funny":103,"Third-Person Shooter":98,"Cartoony":73,"Magic":65,"Great Soundtrack":55,"Multiplayer":50,"Score Attack":49,"Shooter":47,"Addictive":47,"Adventure":33,"RPG":30,"Arcade":28}}
# <Response [200]>
# {"appid":10270,"name":"Disciples III: Reincarnation","developer":"Akella","publisher":"Kalypso Media Digital","score_rank":"","positive":1229,"negative":486,"userscore":0,"owners":"100,000 .. 200,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":30,"languages":"English, Russian","genre":"RPG, Strategy","tags":{"RPG":165,"Strategy":148,"Turn-Based Strategy":141,"Turn-Based":92,"Fantasy":69,"Dark Fantasy":41,"Gothic":29,"Singleplayer":29,"Multiplayer":28,"Atmospheric":11,"Adventure":7,"Classic":7}}
# <Response [200]>
# {"appid":102700,"name":"A.V.A. Alliance of Valiant Arms","developer":"Red Duck Inc.","publisher":"En Masse Entertainment","score_rank":98,"positive":5184,"negative":4920,"userscore":48,"owners":"1,000,000 .. 2,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":5,"languages":"English, French, German, Spanish","genre":"Action, Free to Play","tags":{"Free to Play":295,"FPS":200,"Action":175,"Multiplayer":166,"Shooter":164,"Zombies":129,"First-Person":104,"Co-op":97,"Massively Multiplayer":76,"Singleplayer":74,"Online Co-Op":52,"Adventure":48,"Survival":47,"Open World":44,"Strategy":41,"Military":29,"Funny":27,"Gore":27,"Horror":25,"Controller":21}}
# <Response [200]>
# {"appid":102810,"name":"Gatling Gears","developer":"Vanguard Games","publisher":"Vanguard Games","score_rank":"","positive":141,"negative":25,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":1,"languages":"English, Japanese","genre":"Action, Adventure, Indie","tags":{"Action":26,"Indie":26,"Adventure":25,"Twin Stick Shooter":13,"Co-op":10,"Steampunk":9,"Local Co-Op":8,"Shooter":7}}
# <Response [200]>
# {"appid":102840,"name":"Shank 2","developer":"Klei Entertainment","publisher":"Klei Entertainment","score_rank":"","positive":2808,"negative":609,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":6,"languages":"English","genre":"Action, Adventure, Indie","tags":{"Action":153,"Beat 'em up":126,"Indie":91,"2D":85,"Adventure":71,"Local Co-Op":71,"Side Scroller":63,"Co-op":59,"Platformer":57,"Gore":52,"Hack and Slash":38,"Mature":27,"Shooter":26,"Multiplayer":25,"Controller":23,"Singleplayer":22,"Stylized":22,"Violent":17,"Difficult":15,"Cartoon":9}}
# <Response [200]>
# {"appid":102850,"name":"Warp","developer":"Trapdoor Inc.","publisher":"Electronic Arts","score_rank":"","positive":266,"negative":125,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":0,"languages":"English","genre":"Action, Adventure, Indie","tags":{"Action":49,"Adventure":45,"Indie":37,"Puzzle":22,"Stealth":13,"Aliens":8,"Top-Down":6,"Singleplayer":5,"Gore":5}}
# <Response [200]>
# {"appid":104000,"name":"iBomber Defense","developer":"Cobra Mobile","publisher":"Cobra Mobile","score_rank":"","positive":181,"negative":64,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"599","initialprice":"599","discount":"0","ccu":0,"languages":"English","genre":"Indie, Strategy","tags":{"Strategy":36,"Tower Defense":36,"Indie":30,"Casual":10}}
# <Response [200]>
# {"appid":104020,"name":"Storm in a Teacup","developer":"Cobra Mobile","publisher":"Cobra Mobile","score_rank":"","positive":100,"negative":46,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"499","initialprice":"499","discount":"0","ccu":0,"languages":"English","genre":"Casual, Indie","tags":{"Indie":38,"Casual":38,"Platformer":11}}
# <Response [200]>
# {"appid":104100,"name":"Inside a Star-filled Sky","developer":"Jason Rohrer","publisher":"Jason Rohrer","score_rank":"","positive":65,"negative":31,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"399","initialprice":"399","discount":"0","ccu":0,"languages":"English","genre":"Action, Indie, Strategy","tags":{"Indie":47,"Action":43,"Strategy":35,"Procedural Generation":19,"Pixel Graphics":11,"Rogue-like":7}}
# <Response [200]>
# {"appid":104200,"name":"BEEP","developer":"Big Fat Alien","publisher":"Big Fat Alien","score_rank":"","positive":3921,"negative":701,"userscore":0,"owners":"500,000 .. 1,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":0,"languages":"English","genre":"Adventure, Indie","tags":{"Indie":144,"Platformer":101,"Adventure":88,"2D":84,"Singleplayer":67,"Physics":58,"Puzzle":56,"Action":34,"Robots":31,"Casual":20,"Strategy":18,"Great Soundtrack":17,"Difficult":17,"Shooter":15,"Shoot 'Em Up":14,"Sci-fi":13,"Family Friendly":13,"Arcade":10,"Funny":8,"Atmospheric":7}}
# <Response [200]>
# {"appid":10460,"name":"The Club","developer":"Bizarre Creations","publisher":"SEGA","score_rank":"","positive":101,"negative":72,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"1499","initialprice":"1499","discount":"0","ccu":0,"languages":"English","genre":"Action","tags":{"Action":38,"Arcade":8,"Third-Person Shooter":8,"Singleplayer":7}}
# <Response [200]>
# {"appid":104600,"name":"Portal 2 - The Final Hours","developer":"Geoff Keighley","publisher":"Geoff Keighley","score_rank":"","positive":611,"negative":193,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"199","initialprice":"199","discount":"0","ccu":1,"languages":"English","genre":"","tags":{"Documentary":71,"Game Development":33,"Story Rich":32,"Action":31,"Puzzle":31,"Adventure":30,"Beautiful":30,"Movie":28,"Emotional":26,"Linear":26,"Feature Film":26,"Singleplayer":19,"Short":7,"Co-op":6,"Multiplayer":6,"Online Co-Op":5}}
# <Response [200]>
# {"appid":104700,"name":"Super MNC","developer":"Uber Entertainment","publisher":"Uber Entertainment","score_rank":99,"positive":3309,"negative":1609,"userscore":67,"owners":"1,000,000 .. 2,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":1,"languages":"English","genre":"Free to Play, Action, Strategy, Indie, Sports","tags":{"Free to Play":291,"Action":164,"Multiplayer":131,"MOBA":107,"Shooter":107,"Third-Person Shooter":100,"Strategy":77,"Funny":58,"Indie":58,"Sports":58,"Competitive":52,"Character Customization":46,"Massively Multiplayer":31,"Co-op":27,"Third Person":25,"Comedy":22,"First-Person":21,"Adventure":17,"Class-Based":15,"Singleplayer":13}}
# <Response [200]>
# {"appid":104900,"name":"ORION: Prelude","developer":"DANKIE","publisher":"DANKIE","score_rank":"","positive":21461,"negative":7028,"userscore":0,"owners":"1,000,000 .. 2,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"99","initialprice":"99","discount":"0","ccu":8,"languages":"English","genre":"Action, Adventure, Indie, RPG","tags":{"Dinosaurs":872,"Action":572,"FPS":524,"Multiplayer":512,"Online Co-Op":442,"Co-op":407,"Shooter":377,"Adventure":309,"Indie":308,"Open World":245,"Sci-fi":234,"First-Person":216,"Team-Based":133,"Third-Person Shooter":124,"Singleplayer":121,"PvP":85,"Mechs":85,"Epic":68,"Third Person":60,"Strategy":56}}
# <Response [200]>
# {"appid":10500,"name":"Total War: EMPIRE \u2013 Definitive Edition","developer":"CREATIVE ASSEMBLY, Feral Interactive (Mac), Feral Interactive (Linux)","publisher":"SEGA, Feral Interactive (Mac), Feral Interactive (Linux)","score_rank":"","positive":31915,"negative":3249,"userscore":0,"owners":"1,000,000 .. 2,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"2499","initialprice":"2499","discount":"0","ccu":2713,"languages":"English, French, Italian, German, Spanish - Spain, Russian, Polish, Czech","genre":"Strategy","tags":{"Strategy":1108,"Historical":695,"Military":547,"Grand Strategy":503,"Turn-Based Strategy":404,"War":392,"Tactical":307,"RTS":303,"Multiplayer":279,"Singleplayer":222,"Turn-Based":185,"Naval":166,"America":148,"Real Time Tactics":140,"Action":126,"Great Soundtrack":126,"Turn-Based Tactics":113,"Atmospheric":95,"Classic":77,"Adventure":72}}
# <Response [200]>
# {"appid":105000,"name":"A New Beginning - Final Cut","developer":"Daedalic Entertainment","publisher":"Daedalic Entertainment","score_rank":"","positive":1474,"negative":501,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"99","initialprice":"999","discount":"90","ccu":6,"languages":"English, German, French, Italian, Spanish - Spain, Russian, Polish","genre":"Adventure, Indie","tags":{"Adventure":130,"Point & Click":113,"Indie":43,"Singleplayer":37,"Puzzle":25,"Retro":19,"Great Soundtrack":19,"Classic":19,"1990's":18,"Sci-fi":17,"Cult Classic":17,"Escape Room":16,"Time Travel":14,"2D":12,"Female Protagonist":11,"Atmospheric":9,"Post-apocalyptic":8,"Hand-drawn":7}}
# <Response [200]>
# {"appid":105100,"name":"Lume","developer":"State of Play","publisher":"State of Play","score_rank":"","positive":233,"negative":267,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"599","initialprice":"599","discount":"0","ccu":0,"languages":"English","genre":"Adventure, Casual, Indie","tags":{"Adventure":51,"Indie":45,"Point & Click":43,"Casual":37,"Puzzle":33,"Short":22,"Female Protagonist":17,"Singleplayer":10}}
# <Response [200]>
# {"appid":10530,"name":"Space Siege","developer":"Gas Powered Games","publisher":"SEGA","score_rank":98,"positive":51,"negative":52,"userscore":51,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"1499","initialprice":"1499","discount":"0","ccu":1,"languages":"English","genre":"Action, RPG","tags":{"Action":26,"RPG":26,"Sci-fi":6}}
# <Response [200]>
# {"appid":105300,"name":"Critical Mass","developer":"Manic Game Studios","publisher":"Manic Game Studios","score_rank":"","positive":300,"negative":133,"userscore":0,"owners":"100,000 .. 200,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"199","initialprice":"199","discount":"0","ccu":0,"languages":"English","genre":"Casual, Indie","tags":{"Casual":43,"Indie":39,"Puzzle":39,"Singleplayer":13,"Match 3":8}}
# <Response [200]>
# {"appid":105420,"name":"Ms. Splosion Man","developer":"Twisted Pixel Games","publisher":"Xbox Game Studios","score_rank":"","positive":244,"negative":65,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":0,"languages":"English, German, French, Italian, Korean, Spanish - Spain, Traditional Chinese, Japanese, Portuguese - Portugal","genre":"Action, Indie","tags":{"Action":49,"Indie":45,"Platformer":32,"Female Protagonist":25,"Co-op":12,"Comedy":8,"Local Co-Op":6,"Difficult":5,"Funny":5,"Singleplayer":5}}
# <Response [200]>
# {"appid":105450,"name":"Age of Empires III (2007)","developer":"Ensemble Studios","publisher":"Xbox Game Studios","score_rank":"","positive":29098,"negative":2907,"userscore":0,"owners":"2,000,000 .. 5,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":384,"languages":"English, French, German, Italian, Spanish - Spain","genre":"Simulation, Strategy","tags":{"Strategy":1340,"RTS":964,"Base-Building":756,"Multiplayer":635,"Historical":622,"Resource Management":581,"City Builder":545,"War":525,"Simulation":384,"Singleplayer":366,"Real-Time":364,"Military":294,"Classic":286,"Building":278,"Open World":202,"Co-op":196,"Action":186,"Online Co-Op":180,"Real-Time with Pause":165,"Adventure":146}}
# <Response [200]>
# {"appid":105600,"name":"Terraria","developer":"Re-Logic","publisher":"Re-Logic","score_rank":"","positive":1360828,"negative":35058,"userscore":0,"owners":"20,000,000 .. 50,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":30006,"languages":"English, French, Italian, German, Spanish - Spain, Polish, Portuguese - Brazil, Russian, Simplified Chinese","genre":"Action, Adventure, Indie, RPG","tags":{"Open World Survival Craft":16430,"Sandbox":16129,"Survival":12837,"2D":12670,"Multiplayer":12631,"Adventure":11624,"Pixel Graphics":11431,"Crafting":10646,"Building":10151,"Exploration":8969,"Co-op":7897,"Open World":7649,"Online Co-Op":6182,"Indie":6132,"Action":5702,"RPG":5374,"Singleplayer":5214,"Replay Value":4389,"Platformer":4054,"Atmospheric":3582}}
# <Response [200]>
# {"appid":105700,"name":"Tobe's Vertical Adventure","developer":"Secret Base","publisher":"Secret Base","score_rank":"","positive":82,"negative":54,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"99","initialprice":"99","discount":"0","ccu":0,"languages":"English","genre":"Action, Adventure, Indie","tags":{"Indie":25,"Action":24,"Adventure":24,"Local Co-Op":15,"Platformer":13,"Retro":7,"Pixel Graphics":6,"Local Multiplayer":6}}
# <Response [200]>
# {"appid":106000,"name":"The Cursed Crusade","developer":"","publisher":"","score_rank":99,"positive":195,"negative":111,"userscore":62,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":3,"languages":"","genre":"","tags":{"Action":32,"Adventure":32,"Medieval":12,"Hack and Slash":11}}
# <Response [200]>
# {"appid":10680,"name":"Aliens vs. Predator","developer":"Rebellion","publisher":"SEGA","score_rank":"","positive":17909,"negative":1773,"userscore":0,"owners":"1,000,000 .. 2,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"1499","initialprice":"1499","discount":"0","ccu":66,"languages":"English, French, German, Italian, Russian, Spanish - Spain","genre":"Action","tags":{"Action":526,"FPS":451,"Aliens":400,"Multiplayer":352,"Sci-fi":350,"Horror":345,"Shooter":274,"Singleplayer":260,"Gore":251,"First-Person":248,"Stealth":222,"Atmospheric":171,"Survival":162,"Co-op":158,"Blood":125,"Hunting":124,"Survival Horror":122,"Adventure":101,"Online Co-Op":74,"Strategy":44}}
# <Response [200]>
# {"appid":107100,"name":"Bastion","developer":"Supergiant Games","publisher":"Supergiant Games","score_rank":"","positive":35608,"negative":1733,"userscore":0,"owners":"2,000,000 .. 5,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"1499","initialprice":"1499","discount":"0","ccu":26,"languages":"English, French, German, Italian, Spanish - Spain, Simplified Chinese","genre":"Action, Indie, RPG","tags":{"Great Soundtrack":1684,"Indie":1480,"Action":1304,"Singleplayer":1145,"Narration":1140,"RPG":1034,"Hack and Slash":977,"Story Rich":952,"Dynamic Narration":860,"Isometric":795,"Adventure":711,"Action RPG":640,"Fantasy":374,"Atmospheric":351,"Colorful":250,"Post-apocalyptic":219,"2D":148,"Music":128,"Twin Stick Shooter":109,"Controller":100}}
# <Response [200]>
# {"appid":107200,"name":"Space Pirates and Zombies","developer":"MinMax Games Ltd.","publisher":"MinMax Games Ltd.","score_rank":"","positive":2814,"negative":283,"userscore":0,"owners":"500,000 .. 1,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"499","initialprice":"999","discount":"50","ccu":14,"languages":"English","genre":"Action, Indie, RPG, Strategy","tags":{"Space":261,"Action":181,"Indie":165,"Sci-fi":149,"Top-Down":142,"Strategy":136,"RPG":127,"Zombies":114,"Singleplayer":110,"Procedural Generation":105,"2D":103,"Open World":97,"Pirates":89,"Exploration":81,"Shooter":69,"Sandbox":62,"Addictive":32,"Gore":19,"Adventure":18,"Spaceships":11}}
# <Response [200]>
# {"appid":107300,"name":"Breath of Death VII","developer":"Zeboyd Digital Entertainment LLC","publisher":"Zeboyd Digital Entertainment LLC","score_rank":"","positive":1190,"negative":230,"userscore":0,"owners":"500,000 .. 1,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"299","initialprice":"299","discount":"0","ccu":1,"languages":"English","genre":"Indie, RPG","tags":{"JRPG":308,"RPG":206,"Funny":152,"Indie":150,"Retro":111,"Comedy":108,"Pixel Graphics":74,"Singleplayer":67,"Turn-Based":65,"Parody ":52,"Short":44,"2D":29,"Fantasy":29,"Old School":27,"Adventure":26,"Horror":6,"Top-Down":5}}
# <Response [200]>
# {"appid":107310,"name":"Cthulhu Saves the World","developer":"Zeboyd Digital Entertainment LLC","publisher":"Zeboyd Digital Entertainment LLC","score_rank":"","positive":3141,"negative":280,"userscore":0,"owners":"1,000,000 .. 2,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"299","initialprice":"299","discount":"0","ccu":2,"languages":"English","genre":"Indie, RPG","tags":{"JRPG":730,"Lovecraftian":532,"Comedy":508,"RPG":363,"Indie":266,"Retro":178,"Turn-Based":155,"Fantasy":110,"Funny":106,"Singleplayer":105,"Adventure":62,"Parody ":48,"Pixel Graphics":48,"2D":40,"Great Soundtrack":31,"Dark Humor":28,"Old School":27,"Action":16,"Memes":8,"Horror":5}}
# <Response [200]>
# {"appid":107410,"name":"Arma 3","developer":"Bohemia Interactive","publisher":"Bohemia Interactive","score_rank":"","positive":254698,"negative":26975,"userscore":0,"owners":"10,000,000 .. 20,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"2999","initialprice":"2999","discount":"0","ccu":9449,"languages":"English, French, Italian, German, Spanish - Spain, Czech, Polish, Portuguese - Brazil, Russian, Japanese, Korean, Simplified Chinese, Traditional Chinese, Turkish","genre":"Action, Simulation, Strategy","tags":{"Military":6041,"Action":5791,"Multiplayer":5673,"Shooter":5257,"Simulation":5251,"Realistic":4497,"First-Person":4272,"Open World":3985,"Tactical":3855,"FPS":3810,"War":3553,"Co-op":3409,"Strategy":2785,"Sandbox":2748,"Singleplayer":2129,"Moddable":1984,"Combat":1951,"Online Co-Op":1897,"Team-Based":1784,"Third-Person Shooter":1752}}
# <Response [200]>
# {"appid":107600,"name":"Waves","developer":"Squid In A Box Ltd","publisher":"Squid In A Box Ltd","score_rank":"","positive":1430,"negative":73,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":3,"languages":"English","genre":"Action, Indie","tags":{"Bullet Hell":141,"Shoot 'Em Up":133,"Twin Stick Shooter":132,"Shooter":128,"Arcade":127,"Top-Down":121,"Bullet Time":115,"Cyberpunk":114,"Time Manipulation":112,"Action":109,"Colorful":107,"Abstract":105,"Score Attack":103,"Psychedelic":96,"Retro":91,"Singleplayer":90,"Great Soundtrack":73,"Fast-Paced":60,"Arena Shooter":52,"2D":42}}
# <Response [200]>
# {"appid":107800,"name":"Rochard","developer":"Recoil Games","publisher":"Warner Bros. Interactive Entertainment","score_rank":"","positive":1587,"negative":142,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":0,"languages":"English, German, French, Italian, Spanish - Spain, Dutch, Czech, Polish, Portuguese - Portugal, Portuguese - Brazil, Russian, Turkish, Hungarian","genre":"Action, Casual, Indie","tags":{"Platformer":100,"Indie":88,"Action":81,"Puzzle":65,"Physics":57,"Sci-fi":45,"Casual":40,"Singleplayer":34,"Puzzle-Platformer":30,"2D":21,"Side Scroller":19,"2.5D":17,"Great Soundtrack":15,"Space":13,"Adventure":12}}
# <Response [200]>
# {"appid":107900,"name":"War Inc. Battlezone","developer":"Online Warmongers Group Inc.","publisher":"Online Warmongers Group Inc.","score_rank":98,"positive":1515,"negative":1577,"userscore":48,"owners":"1,000,000 .. 2,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":2,"languages":"English","genre":"Action, Free to Play","tags":{"Free to Play":239,"Action":137,"Multiplayer":117,"Shooter":116,"FPS":107,"War":88,"Third-Person Shooter":68,"Massively Multiplayer":60,"Co-op":56,"First-Person":54,"Zombies":47,"Singleplayer":43,"Open World":39,"Online Co-Op":37,"Survival":36,"Adventure":23,"Third Person":15,"Funny":14,"Horror":10,"Atmospheric":9}}
# <Response [200]>
# {"appid":108110,"name":"Starpoint Gemini","developer":"Little Green Men Games","publisher":"Little Green Men Games","score_rank":"","positive":48,"negative":100,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"1399","initialprice":"1399","discount":"0","ccu":0,"languages":"English, German","genre":"RPG, Simulation","tags":{"RPG":49,"Simulation":49,"Space":27,"Sci-fi":19,"Space Sim":14,"Indie":10}}
# <Response [200]>
# {"appid":108200,"name":"Ticket to Ride: Classic Edition","developer":"Days of Wonder","publisher":"Days of Wonder, Twin Sails Interactive","score_rank":"","positive":4624,"negative":749,"userscore":0,"owners":"500,000 .. 1,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":107,"languages":"English, French, German, Italian, Spanish - Spain","genre":"Casual, Indie, Strategy","tags":{"Board Game":363,"Strategy":291,"Tabletop":279,"Casual":232,"Multiplayer":193,"Turn-Based":167,"Indie":155,"Trains":147,"Family Friendly":112,"Singleplayer":98,"Touch-Friendly":80,"Addictive":79,"Local Multiplayer":77,"Turn-Based Tactics":72,"Turn-Based Strategy":71,"2D":67,"Competitive":66,"Replay Value":64,"Asynchronous Multiplayer":61,"Hand-drawn":57}}
# <Response [200]>
# {"appid":108210,"name":"Memoir '44 Online","developer":"Days of Wonder","publisher":"Days of Wonder, Twin Sails Interactive","score_rank":"","positive":390,"negative":222,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":0,"languages":"English, French","genre":"Casual, Simulation, Strategy","tags":{"Strategy":54,"Casual":39,"Board Game":37,"Simulation":36,"World War II":16,"Tactical":12,"Free to Play":10,"Military":9,"Turn-Based":8,"Multiplayer":6,"Wargame":5}}
# <Response [200]>
# {"appid":108500,"name":"Vessel","developer":"Strange Loop Games","publisher":"IndiePub","score_rank":"","positive":695,"negative":97,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"499","initialprice":"499","discount":"0","ccu":0,"languages":"English, French, German, Italian, Spanish - Spain","genre":"Action, Indie, Strategy","tags":{"Puzzle":87,"Indie":73,"Platformer":63,"Steampunk":50,"Action":40,"Physics":38,"Strategy":34,"Singleplayer":28,"Puzzle-Platformer":27,"Adventure":15,"2D":14,"Sci-fi":11,"Great Soundtrack":9}}
# <Response [200]>
# {"appid":108600,"name":"Project Zomboid","developer":"The Indie Stone","publisher":"The Indie Stone","score_rank":"","positive":346752,"negative":21424,"userscore":0,"owners":"10,000,000 .. 20,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"1999","initialprice":"1999","discount":"0","ccu":20633,"languages":"English, French, Italian, German, Spanish - Spain, Danish, Dutch, Hungarian, Norwegian, Polish, Portuguese - Portugal, Russian, Turkish, Japanese, Simplified Chinese, Portuguese - Brazil, Finnish, Korean, Thai, Traditional Chinese, Ukrainian","genre":"Indie, RPG, Simulation, Early Access","tags":{"Survival":4536,"Zombies":3701,"Open World":3089,"Multiplayer":2791,"Open World Survival Craft":2745,"Sandbox":2336,"Post-apocalyptic":1957,"Co-op":1844,"Crafting":1570,"Building":1447,"Indie":1426,"Simulation":1391,"RPG":1374,"Survival Horror":1305,"Realistic":1154,"Isometric":1073,"Singleplayer":1004,"2D":891,"Adventure":808,"Early Access":760}}
# <Response [200]>
# {"appid":108700,"name":"Death Rally","developer":"Remedy Entertainment, Mountain Sheep, Cornfox & Brothers","publisher":"Remedy Entertainment","score_rank":"","positive":571,"negative":229,"userscore":0,"owners":"100,000 .. 200,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":2,"languages":"English","genre":"Action, Racing","tags":{"Racing":97,"Action":71,"Remake":34,"Arcade":25,"Combat Racing":24,"Top-Down":21,"Vehicular Combat":12,"Multiplayer":11,"Singleplayer":8,"Isometric":7,"Shooter":5}}
# <Response [200]>
# {"appid":108710,"name":"Alan Wake","developer":"Remedy Entertainment","publisher":"Remedy Entertainment","score_rank":"","positive":44119,"negative":4667,"userscore":0,"owners":"1,000,000 .. 2,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"1499","initialprice":"1499","discount":"0","ccu":112,"languages":"English, German, French, Italian, Korean, Spanish - Spain, Russian, Japanese, Polish, Traditional Chinese, Spanish - Latin America","genre":"Action, Adventure","tags":{"Action":1095,"Horror":1062,"Third Person":910,"Adventure":909,"Story Rich":884,"Thriller":792,"Atmospheric":780,"Singleplayer":709,"Psychological Horror":628,"Great Soundtrack":428,"Mystery":373,"Episodic":326,"Third-Person Shooter":319,"Dark":305,"Supernatural":301,"Cinematic":282,"Survival Horror":242,"Narration":242,"Shooter":208,"Survival":113}}
# <Response [200]>
# {"appid":109200,"name":"Legend of Fae","developer":"Endlessfluff Games","publisher":"","score_rank":"","positive":90,"negative":30,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":0,"languages":"English","genre":"Casual, Indie","tags":{"Indie":35,"Casual":35,"Female Protagonist":19,"Match 3":18,"Puzzle":16,"Fantasy":12,"RPG":9}}
# <Response [200]>
# {"appid":109500,"name":"Fowl Space","developer":"Pixelante Game Studios","publisher":"Pixelante Game Studios","score_rank":"","positive":106,"negative":77,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"499","initialprice":"499","discount":"0","ccu":0,"languages":"English","genre":"Action, Indie","tags":{"Action":24,"Indie":23,"Memes":7}}
# <Response [200]>
# {"appid":109700,"name":"Achron","developer":"Hazardous Software Inc.","publisher":"Hazardous Software Inc.","score_rank":"","positive":71,"negative":40,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"1999","initialprice":"1999","discount":"0","ccu":0,"languages":"English","genre":"Indie, Strategy","tags":{"Strategy":39,"Indie":29,"Time Travel":22,"RTS":20,"Multiplayer":16,"Time Manipulation":15,"Sci-fi":14,"Moddable":7}}
# <Response [200]>
# {"appid":11040,"name":"Sherlock Holmes - Nemesis","developer":"Frogwares","publisher":"Frogwares","score_rank":"","positive":465,"negative":182,"userscore":0,"owners":"100,000 .. 200,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":0,"languages":"English, French, Italian, German, Russian","genre":"Adventure, RPG","tags":{"Adventure":91,"RPG":63,"Detective":47,"Point & Click":35,"Mystery":27,"Puzzle":26,"Investigation":16,"First-Person":9,"Singleplayer":5}}
# <Response [200]>
# {"appid":110400,"name":"inMomentum","developer":"Digital Arrow","publisher":"White Rabbit Interactive","score_rank":"","positive":136,"negative":49,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":0,"languages":"English","genre":"Indie, Racing","tags":{"Racing":41,"Indie":33,"Parkour":22,"Fast-Paced":16,"First-Person":12,"Multiplayer":10,"Platformer":8,"Singleplayer":6,"Great Soundtrack":5}}
# <Response [200]>
# {"appid":11050,"name":"Dracula: Origin","developer":"Frogwares","publisher":"Frogwares","score_rank":"","positive":236,"negative":89,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":1,"languages":"English, French, German, Italian, Polish, Russian, Spanish - Spain","genre":"Adventure, Casual","tags":{"Adventure":75,"Casual":53,"Vampire":51,"Point & Click":36,"Puzzle":34,"Story Rich":19,"Hidden Object":12,"Indie":11,"2.5D":11,"Atmospheric":8,"Singleplayer":7,"Based On A Novel":5}}
# <Response [200]>
# {"appid":110500,"name":"Data Jammers: FastForward","developer":"Digital Eel","publisher":"Digital Eel","score_rank":"","positive":69,"negative":35,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":0,"languages":"English","genre":"Action, Indie","tags":{"Action":32,"Indie":28,"Arcade":9,"Racing":5}}
# <Response [200]>
# {"appid":110600,"name":"Astro Tripper","developer":"PomPom","publisher":"Pom Pom Games","score_rank":"","positive":38,"negative":29,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"499","initialprice":"499","discount":"0","ccu":0,"languages":"English, German, French, Italian, Spanish - Spain","genre":"Action, Indie","tags":{"Action":30,"Indie":30,"Shoot 'Em Up":14,"Arcade":9,"Shooter":6}}
# <Response [200]>
# {"appid":110630,"name":"Mutant Storm: Reloaded","developer":"PomPom Games","publisher":"PomPom Games","score_rank":"","positive":35,"negative":14,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"499","initialprice":"499","discount":"0","ccu":0,"languages":"English, French, German, Italian, Spanish - Spain","genre":"Action, Indie","tags":{"Indie":27,"Action":25,"Twin Stick Shooter":7,"Shoot 'Em Up":6,"Arcade":5}}
# <Response [200]>
# {"appid":110800,"name":"L.A. Noire","developer":"Team Bondi, Rockstar Leeds","publisher":"Rockstar Games","score_rank":"","positive":29023,"negative":4796,"userscore":0,"owners":"1,000,000 .. 2,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"799","initialprice":"799","discount":"0","ccu":205,"languages":"English, French, German, Italian, Russian, Spanish - Spain","genre":"Adventure, Strategy","tags":{"Detective":991,"Crime":696,"Open World":668,"Noir":658,"Adventure":576,"Story Rich":528,"Mystery":448,"Investigation":418,"Third Person":414,"Singleplayer":363,"Cinematic":355,"Action":337,"Atmospheric":306,"Mature":279,"Nudity":161,"Puzzle":130,"Third-Person Shooter":125,"Strategy":122,"Thriller":121,"3D Vision":57}}
# <Response [200]>
# {"appid":111000,"name":"The Clockwork Man","developer":"Total Eclipse","publisher":"Total Eclipse","score_rank":"","positive":49,"negative":37,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"699","initialprice":"699","discount":"0","ccu":0,"languages":"English, Dutch, French, German, Italian, Japanese, Korean, Portuguese - Portugal, Spanish - Spain, Swedish","genre":"Indie, Casual","tags":{"Casual":27,"Indie":24,"Hidden Object":21,"Puzzle":8,"Steampunk":8,"Point & Click":7,"Adventure":5}}
# <Response [200]>
# {"appid":111010,"name":"The Clockwork Man: The Hidden World","developer":"Total Eclipse P.C.","publisher":"Total Eclipse P.C.","score_rank":"","positive":50,"negative":29,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":0,"languages":"English, Dutch, French, German, Italian, Spanish - Spain, Swedish, Portuguese - Portugal","genre":"Adventure, Casual, Indie","tags":{"Adventure":29,"Casual":26,"Hidden Object":26,"Indie":25,"Point & Click":7}}
# <Response [200]>
# {"appid":111100,"name":"Snuggle Truck","developer":"Owlchemy Labs","publisher":"Owlchemy Labs","score_rank":"","positive":377,"negative":89,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"499","initialprice":"499","discount":"0","ccu":0,"languages":"English","genre":"Casual, Indie, Racing","tags":{"Casual":48,"Racing":44,"Indie":37,"Driving":19,"Singleplayer":12,"Level Editor":10,"2D":5}}
# <Response [200]>
# {"appid":11130,"name":"Sherlock Holmes: The Mystery of the Mummy","developer":"Frogwares","publisher":"Frogwares","score_rank":"","positive":136,"negative":346,"userscore":0,"owners":"100,000 .. 200,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":3,"languages":"English, French, German, Italian, Polish, Portuguese - Brazil, Russian, Spanish - Spain","genre":"Adventure","tags":{"Adventure":91,"Point & Click":40,"Detective":40,"Puzzle":22,"Mystery":22,"First-Person":17,"Free to Play":12,"Retro":12,"Singleplayer":6}}
# <Response [200]>
# {"appid":111300,"name":"Smash Cars","developer":"Creat Studios Inc","publisher":"","score_rank":"","positive":39,"negative":15,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":1,"languages":"English, Russian","genre":"Action, Racing, Sports","tags":{"Racing":26,"Action":23,"Sports":23}}
# <Response [200]>
# {"appid":11140,"name":"Sherlock Holmes: The Awakened (2008)","developer":"Frogwares","publisher":"Frogwares","score_rank":"","positive":582,"negative":208,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":5,"languages":"English, French, German, Italian, Polish, Russian","genre":"Adventure","tags":{"Adventure":84,"Lovecraftian":46,"Detective":43,"Point & Click":32,"Mystery":23,"Puzzle":16,"First-Person":16,"Investigation":16,"Horror":15,"Third Person":6,"Singleplayer":6}}
# <Response [200]>
# {"appid":111400,"name":"Bunch of Heroes","developer":"Nimble Giant Entertainment","publisher":"Nimble Giant Entertainment","score_rank":"","positive":209,"negative":220,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"499","initialprice":"499","discount":"0","ccu":0,"languages":"English, Czech, Polish, Spanish - Spain","genre":"Action, Indie","tags":{"Action":48,"Indie":40,"Co-op":25,"Shooter":16,"Multiplayer":16,"Top-Down Shooter":8}}
# <Response [200]>
# {"appid":11150,"name":"Sherlock Holmes: The Silver Earring","developer":"Frogwares","publisher":"Frogwares","score_rank":"","positive":408,"negative":267,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":1,"languages":"English, Bulgarian, Czech, French, German, Italian, Polish, Russian, Spanish - Spain","genre":"Adventure","tags":{"Adventure":80,"Point & Click":36,"Detective":33,"Puzzle":18,"Mystery":16,"Retro":12,"Singleplayer":5}}
# <Response [200]>
# ...
# <Response [200]>
# {"appid":258910,"name":"Citizens of Earth","developer":"Eden Industries","publisher":"Brain Seal Ltd","score_rank":"","positive":303,"negative":94,"userscore":0,"owners":"100,000 .. 200,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":3,"languages":"English, French, Italian, German, Spanish - Spain","genre":"RPG","tags":{"RPG":48,"Comedy":24,"Turn-Based":20,"Singleplayer":12,"Cartoony":12,"2D":10,"Indie":8,"Retro":7,"JRPG":7,"Funny":6}}
# <Response [200]>
# {"appid":258950,"name":"Montague's Mount","developer":"PolyPusher Studios","publisher":"PolyPusher Studios","score_rank":"","positive":247,"negative":177,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"499","initialprice":"499","discount":"0","ccu":0,"languages":"English, French, German, Spanish - Spain, Polish, Portuguese - Brazil, Russian","genre":"Adventure, Indie","tags":{"Indie":47,"Adventure":45,"Walking Simulator":29,"Horror":22,"Atmospheric":16,"Puzzle":12,"Exploration":5}}
# <Response [200]>
# {"appid":258970,"name":"Gauntlet Slayer Edition","developer":"Arrowhead Game Studios","publisher":"WB Games","score_rank":"","positive":8042,"negative":1800,"userscore":0,"owners":"1,000,000 .. 2,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"1999","initialprice":"1999","discount":"0","ccu":44,"languages":"English, French, German, Spanish - Spain, Polish, Portuguese - Brazil, Russian, Italian","genre":"Action, Adventure, RPG","tags":{"Co-op":336,"Dungeon Crawler":268,"Hack and Slash":240,"Local Co-Op":234,"Action":221,"RPG":212,"Multiplayer":185,"Adventure":146,"Top-Down":139,"4 Player Local":137,"Online Co-Op":129,"Arcade":121,"Remake":110,"Fantasy":106,"Local Multiplayer":105,"Classic":102,"Action RPG":70,"Isometric":49,"Old School":35,"Casual":24}}
# <Response [200]>
# {"appid":2590,"name":"Alpha Prime","developer":"Black Element","publisher":"Bohemia Interactive","score_rank":"","positive":805,"negative":655,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"499","initialprice":"499","discount":"0","ccu":0,"languages":"English","genre":"Action","tags":{"Action":86,"FPS":74,"Sci-fi":45,"Shooter":44,"First-Person":29,"Singleplayer":28,"Gore":22,"Violent":21,"Difficult":18,"Space":17}}
# <Response [200]>
# {"appid":25900,"name":"King's Bounty: The Legend","developer":"Fulqrum Publishing","publisher":"Fulqrum Publishing","score_rank":"","positive":2976,"negative":300,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"699","initialprice":"699","discount":"0","ccu":116,"languages":"English, Russian, French, Italian, German, Spanish - Spain, Czech, Japanese, Hungarian, Polish","genre":"RPG, Strategy","tags":{"RPG":214,"Strategy":192,"Turn-Based Strategy":128,"Fantasy":111,"Turn-Based":78,"Adventure":75,"Hex Grid":66,"Singleplayer":53,"Tactical RPG":52,"Tactical":51,"Turn-Based Combat":39,"Atmospheric":37,"Great Soundtrack":35,"Classic":29,"Open World":23,"Addictive":16,"Comedy":10,"Strategy RPG":7,"Exploration":5}}
# <Response [200]>
# {"appid":259060,"name":"Dominions 4: Thrones of Ascension","developer":"Illwinter Game Design","publisher":"Illwinter Game Design","score_rank":"","positive":1309,"negative":134,"userscore":0,"owners":"100,000 .. 200,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"3499","initialprice":"3499","discount":"0","ccu":3,"languages":"English","genre":"Indie, Strategy","tags":{"Strategy":132,"Turn-Based Strategy":108,"Indie":91,"Grand Strategy":82,"Fantasy":70,"Multiplayer":67,"Moddable":52,"Turn-Based":52,"Difficult":48,"Singleplayer":45,"God Game":43,"4X":41,"Addictive":19,"RPG":9,"Sandbox":6,"Mythology":6}}
# <Response [200]>
# {"appid":259080,"name":"Just Cause 2: Multiplayer Mod","developer":"Avalanche Studios","publisher":"Square Enix","score_rank":"","positive":13577,"negative":1246,"userscore":0,"owners":"2,000,000 .. 5,000,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":15,"languages":"English, French, German, Italian, Spanish - Spain, Polish, Russian","genre":"Action, Adventure","tags":{"Open World":2115,"Multiplayer":306,"Action":295,"Third-Person Shooter":185,"Adventure":182,"Mod":179,"Sandbox":170,"Massively Multiplayer":144,"Shooter":127,"Free to Play":115,"Third Person":101,"Co-op":74,"Funny":64,"Exploration":52,"Racing":48,"Epic":48,"Moddable":23,"Singleplayer":22,"FPS":18,"Zombies":14}}
# <Response [200]>
# {"appid":25910,"name":"Supreme Ruler 2020 Gold","developer":"BattleGoat Studios","publisher":"BattleGoat Studios","score_rank":"","positive":195,"negative":55,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":11,"languages":"English, French, German, Spanish - Spain","genre":"Strategy","tags":{"Modern":166,"Tactical":160,"Management":158,"Wargame":153,"Strategy":150,"Singleplayer":142,"Military":137,"Grand Strategy":131,"Simulation":125,"Politics":125,"War":124,"Political":119,"Multiplayer":111,"RTS":100,"Sandbox":91,"Top-Down":84,"Moddable":78,"Hex Grid":75,"Real-Time with Pause":69,"Political Sim":58}}
# <Response [200]>
# {"appid":259130,"name":"Wasteland 1 - The Original Classic","developer":"inXile Entertainment","publisher":"inXile Entertainment","score_rank":"","positive":353,"negative":95,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"599","initialprice":"599","discount":"0","ccu":2,"languages":"English","genre":"Adventure, Indie, RPG, Strategy","tags":{"RPG":126,"Post-apocalyptic":97,"Classic":72,"Turn-Based":55,"Adventure":51,"Strategy":46,"Sci-fi":41,"Retro":41,"Indie":32,"CRPG":31,"2D":30,"Singleplayer":28,"Old School":28,"1980s":15,"Pixel Graphics":14,"Action":10,"Open World":9,"Great Soundtrack":7}}
# <Response [200]>
# {"appid":259170,"name":"Alone in the Dark (2008)","developer":"Eden Games, Hydravision Entertainment","publisher":"THQ Nordic","score_rank":"","positive":549,"negative":822,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"249","initialprice":"999","discount":"75","ccu":3,"languages":"English, French, Italian, German, Spanish - Spain","genre":"Action, Adventure","tags":{"Adventure":53,"Action":49,"Horror":45,"Survival Horror":26,"Atmospheric":19,"Great Soundtrack":16,"Open World":16,"Singleplayer":15,"First-Person":13,"Third Person":12,"FPS":12,"Survival":12,"Crafting":11,"Story Rich":11,"Psychological Horror":10,"Realistic":10,"Lovecraftian":10,"Cinematic":9,"Cult Classic":9,"Choices Matter":8}}
# <Response [200]>
# {"appid":259190,"name":"Alone in the Dark: The New Nightmare","developer":"Darkworks, Spiral House","publisher":"THQ Nordic","score_rank":"","positive":428,"negative":180,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"174","initialprice":"699","discount":"75","ccu":2,"languages":"English","genre":"Action, Adventure","tags":{"Adventure":44,"Horror":39,"Action":35,"Survival Horror":25,"Classic":14,"Puzzle":9,"Female Protagonist":5,"Lovecraftian":5}}
# <Response [200]>
# {"appid":25930,"name":"East India Company","developer":"Nitro Games","publisher":"Nitro Games","score_rank":"","positive":100,"negative":88,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":4,"languages":"English, French, German","genre":"Strategy","tags":{"Trading":251,"Capitalism":243,"Political Sim":240,"Historical":236,"Economy":232,"Political":224,"RTS":220,"Diplomacy":217,"Strategy":212,"Medieval":210,"Grand Strategy":209,"Management":205,"Simulation":200,"Naval Combat":198,"City Builder":196,"Exploration":193,"Sailing":188,"Pirates":183,"Tactical":178,"Adventure":174}}
# <Response [200]>
# {"appid":259320,"name":"Heli Heroes","developer":"Reality Pump","publisher":"Topware Interactive","score_rank":"","positive":321,"negative":256,"userscore":0,"owners":"100,000 .. 200,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"699","initialprice":"699","discount":"0","ccu":1,"languages":"English, German, French, Spanish - Spain, Czech, Dutch, Hungarian, Polish, Russian","genre":"Action, Casual","tags":{"Action":305,"Casual":42,"Shoot 'Em Up":11,"Arcade":8}}
# <Response [200]>
# {"appid":259340,"name":"Chicken Shoot Gold","developer":"ToonTRAXX Studios","publisher":"Topware Interactive","score_rank":"","positive":628,"negative":301,"userscore":0,"owners":"100,000 .. 200,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"1299","initialprice":"1299","discount":"0","ccu":1,"languages":"English, French, Italian, German, Spanish - Spain, Polish","genre":"Action, Casual, Indie","tags":{"Action":575,"Casual":43,"Indie":39,"Psychological Horror":19,"Shooter":14,"Nudity":9,"Mature":5}}
# <Response [200]>
# {"appid":259410,"name":"Sneaky Sneaky","developer":"Naiad Entertainment LLC","publisher":"Naiad Entertainment LLC","score_rank":"","positive":249,"negative":29,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"499","initialprice":"499","discount":"0","ccu":0,"languages":"English","genre":"Adventure, Casual, Indie, RPG, Strategy","tags":{"Strategy":28,"Casual":27,"RPG":23,"Indie":22,"Stealth":21,"Adventure":20,"Puzzle":11}}
# <Response [200]>
# {"appid":259430,"name":"Zigfrak","developer":"Entheogen Studios LLC","publisher":"Entheogen Studios LLC","score_rank":"","positive":173,"negative":65,"userscore":0,"owners":"20,000 .. 50,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":0,"languages":"English","genre":"Action, Indie, RPG","tags":{"Action":42,"RPG":40,"Indie":40,"Space":26,"Sci-fi":21,"Open World":16,"Space Sim":13,"Simulation":8,"Loot":7}}
# <Response [200]>
# {"appid":259450,"name":"Drifter","developer":"Celsius Game Studios","publisher":"Celsius Game Studios","score_rank":"","positive":113,"negative":93,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"1199","initialprice":"1199","discount":"0","ccu":0,"languages":"English","genre":"Action, Indie, Simulation, Early Access","tags":{"Simulation":45,"Indie":43,"Space":43,"Sandbox":38,"Action":36,"Early Access":36,"Open World":29,"Trading":23,"Space Sim":22,"Exploration":21,"Sci-fi":20,"Procedural Generation":20,"Singleplayer":14,"Atmospheric":13,"Mining":13,"Great Soundtrack":12,"Casual":11,"Relaxing":11}}
# <Response [200]>
# {"appid":259470,"name":"Particulars","developer":"SeeThrough Studios","publisher":"SeeThrough Studios","score_rank":"","positive":68,"negative":33,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":0,"languages":"English","genre":"Indie","tags":{"Indie":35,"Puzzle":19,"Physics":10}}
# <Response [200]>
# {"appid":259490,"name":"Beast Boxing Turbo","developer":"","publisher":"Secret Mode","score_rank":"","positive":263,"negative":31,"userscore":0,"owners":"0 .. 20,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":0,"languages":"English","genre":"","tags":{"Sports":48,"Action":39,"Boxing":37,"Indie":36,"Fighting":8,"Female Protagonist":8}}
# <Response [200]>
# {"appid":259510,"name":"Shufflepuck Cantina Deluxe","developer":"Agharta Studio","publisher":"Agharta Studio","score_rank":"","positive":451,"negative":82,"userscore":0,"owners":"100,000 .. 200,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"999","initialprice":"999","discount":"0","ccu":0,"languages":"English, French, Italian, German, Spanish - Spain","genre":"Action, Indie, Sports","tags":{"Sports":397,"Indie":60,"VR":52,"Action":43,"Arcade":33,"Casual":30,"Sci-fi":26,"Remake":18,"Addictive":13}}
# <Response [200]>
# {"appid":259530,"name":"Savant - Ascent","developer":"D-Pad Studio","publisher":"Studio V5","score_rank":"","positive":2583,"negative":219,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"199","initialprice":"199","discount":"0","ccu":1,"languages":"English, Japanese, Korean, Norwegian, Simplified Chinese, Traditional Chinese","genre":"Action, Indie","tags":{"Action":125,"Indie":111,"Great Soundtrack":109,"Music":102,"Shoot 'Em Up":93,"Fast-Paced":85,"Score Attack":64,"Bullet Hell":54,"Arcade":52,"Short":52,"Replay Value":47,"2D":38,"Singleplayer":35,"Difficult":30,"Platformer":25,"Pixel Graphics":23,"Retro":18,"GameMaker":16,"Controller":8,"Casual":7}}
# <Response [200]>
# {"appid":259550,"name":"Hero of the Kingdom","developer":"Lonely Troops","publisher":"Lonely Troops","score_rank":"","positive":4376,"negative":296,"userscore":0,"owners":"200,000 .. 500,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"799","initialprice":"799","discount":"0","ccu":2,"languages":"English, French, German, Spanish - Spain, Czech, Polish, Russian, Turkish, Ukrainian, Hungarian, Dutch, Danish, Italian, Portuguese - Brazil, Simplified Chinese, Slovak","genre":"Adventure, Casual, Indie, RPG","tags":{"Casual":182,"Adventure":133,"Indie":108,"Point & Click":100,"RPG":93,"Singleplayer":93,"Hidden Object":76,"Resource Management":71,"Fantasy":70,"Short":63,"Isometric":35,"Strategy":30,"Medieval":24,"Story Rich":21,"Clicker":17,"Colorful":13,"Puzzle":13,"2D":7}}
# <Response [200]>
# {"appid":259570,"name":"EDEN STAR","developer":"Flix Interactive","publisher":"Flix Interactive","score_rank":"","positive":590,"negative":532,"userscore":0,"owners":"50,000 .. 100,000","average_forever":0,"average_2weeks":0,"median_forever":0,"median_2weeks":0,"price":"0","initialprice":"0","discount":"0","ccu":0,"languages":"English","genre":"Action, Adventure, Indie, Strategy, Early Access","tags":{"Survival":139,"Base-Building":120,"Sci-fi":99,"Action":92,"First-Person":89,"Early Access":85,"Sandbox":84,"Strategy":84,"Open World":82,"Adventure":80,"Indie":78,"Building":72,"Shooter":71,"Multiplayer":68,"Singleplayer":60,"Physics":54,"Tower Defense":50,"FPS":39,"Space":25,"Co-op":24}}
#    app_id  positive  negative                    owners price  \
# 0      10    242768      6388  10,000,000 .. 20,000,000   999
# 1    1002        89        30          20,000 .. 50,000    99
# 2  100400        61        24               0 .. 20,000  5999
# 3   10090     46341      3870    2,000,000 .. 5,000,000  1499
# 4  100980       129        17               0 .. 20,000     0
#
#                                                 tags
# 0  {'Action': 5499, 'FPS': 4924, 'Multiplayer': 3...
# 1  {'2D Fighter': 47, 'Martial Arts': 41, 'Intent...
# 2       {'Animation & Modeling': 23, 'Software': 11}
# 3  {'Zombies': 1197, 'World War II': 902, 'FPS': ...
# 4  {'Animation & Modeling': 38, 'Utilities': 22, ...
